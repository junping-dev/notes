# %% [markdown]
# ---
# title: "PyTorch 基础"
# date: 2025-11-28
# categories: [深度学习, PyTorch]
# tags: [PyTorch, 神经网络, 机器学习]
# format:
#   html:
#     theme:
#       - cosmo
#       - brand
#     css: styles.css
#     toc: true
# ---

# %%
# 导入 PyTorch
import torch
# 创建一个张量
x = torch.rand(2, 3)
print(x)
